# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

# %%
# Depth vs Whatever metric here

measure = "F1 Score"
algo = "Depth vs. F1 Score (Baseline)"

labels = ['D3', 'D5', 'D7']

mean_acc_mwpm = [0.677, 0.704, 0.699]
mean_acc_plut = [0.080, 0.239, 0.217]
mean_acc_nn = [0.089, 0.625, 0.821]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, mean_acc_mwpm, width, label='MWPM')
rects2 = ax.bar(x, mean_acc_plut, width, label='PLUT')
rects3 = ax.bar(x + width, mean_acc_nn, width, label='NN')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(measure)
ax.set_xlabel('Surface Code Depth')
ax.set_title(algo)
ax.set_xticks(x, labels)
ax.set_ylim([0.0,1.1])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)

#plt.rcParams["figure.figsize"] = (10,8)
plt.show()

# %%
measure = "F1 Score"
algo = "Decoder vs. F1 Score for Depth 3\n(Exhaustive Data Set)"

data = {'MWPM': 0.242, 'PLUT': 0.358, 'NN': 0.667}

names = list(data.keys())
values = list(data.values())

fig, ax = plt.subplots()
rects = ax.bar(names, values)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(measure)
ax.set_xlabel('Decoder')
ax.set_title(algo)
ax.set_ylim([0.0,0.72])

ax.bar_label(rects, padding=3)


#plt.rcParams["figure.figsize"] = (10,8)
plt.show()

# %%
# create data
x = [2,4,8,12]
#y_v1 = [1.039,0.484,0.459,0.314]
y_v2_1k = [0.768,0.256,0.256,0.256]
y_v2_100k = [0.3,0.313,0.287,0.168]
y_v3_1k = [0.895,0.895,0.895,0.488]
#y_v3_10k = [3.592,8.72,15.264,15.264]
  
# plot lines
fig = plt.figure()
plt.plot(x, y_v2_1k, label = "Rand (w/ repl @ 1k)", linestyle="--")
plt.plot(x, y_v2_100k, label = "Rand (w/ repl @ 100k)", linestyle="-.")
plt.plot(x, y_v3_1k, label = "Rand (w/o repl)", linestyle=":")
#plt.plot(x, y_v1, label = "Exhaustive", linestyle="-")
#plt.plot(x, y_v3_10k, label = "Rand (w/o repl @ 10k)", linestyle=" ")
plt.legend()
fig.suptitle('Parallel Algorithm Speedup for Depth Three', fontsize=20)
plt.xlabel('Processors', fontsize=18)
plt.ylabel('Speedup', fontsize=16)
plt.ylim([0.0,1.75])
plt.show()

# %%
# create data
x = [2,4,8,12]
y_v2_1k = [0.768,0.256,0.256,0.256]
y_v2_100k = [1.358,0.824,0.753,0.513]
y_v3_1k = [0.896,0.896,0.896,0.488]

  
# plot lines
fig = plt.figure()
#plt.plot(x, y_v1, label = "Exhaustive", linestyle="-")
plt.plot(x, y_v2_1k, label = "Rand (w/ repl @ 1k)", linestyle="--")
plt.plot(x, y_v2_100k, label = "Rand (w/ repl @ 100k)", linestyle="-.")
plt.plot(x, y_v3_1k, label = "Rand (w/o repl)", linestyle=":")
plt.legend()
fig.suptitle('Parallel Algorithm Speedup for Depth Five', fontsize=20)
plt.xlabel('Processors', fontsize=18)
plt.ylabel('Speedup', fontsize=16)
plt.show()

# %%
# create data
x = [2,4,8,12]
y_v2_1k = [0.864,0.576,0.864,0.864]
y_v2_100k = [1.741,1.485,1.485,1.098]
y_v3_1k = [0.086,0.086,0.432,0.086]

  
# plot lines
fig = plt.figure()
#plt.plot(x, y_v1, label = "Exhaustive", linestyle="-")
plt.plot(x, y_v2_1k, label = "Rand (w/ repl @ 1k)", linestyle="--")
plt.plot(x, y_v2_100k, label = "Rand (w/ repl @ 100k)", linestyle="-.")
plt.plot(x, y_v3_1k, label = "Rand (w/o repl)", linestyle=":")
plt.legend()
fig.suptitle('Parallel Algorithm Speedup for Depth Seven', fontsize=20)
plt.xlabel('Processors', fontsize=18)
plt.ylabel('Speedup', fontsize=16)
plt.show()
